# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n1 = []
n2 = []
teacher = []
# entrada = np.arange(80)
entrada = []
binario = " "

Tensor_Suma_Entrada = np.ones((1000, 22))*(-1)
Tensor_Suma_Input = np.ones((700, 22))*(-1)
Tensor_Suma_Test = np.ones((300, 22))*(-1)

Tensor_Teacher_Entrada = np.ones((1000, 11))*(-1)
Tensor_Teacher_Input = np.ones((700, 11))*(-1)
Tensor_Teacher_Test = np.ones((300, 11))*(-1)


for i in range(1000):

    n1.append(random.randrange(1, 1000))
    x1 = n1[i]
    binario = bin(n1[i])[2:]
    n1[i] = str(binario)

    n2.append(random.randrange(1, 1000))
    x2 = n2[i]
    binario = bin(n2[i])[2:]
    n2[i] = str(binario)

    x3 = x1+x2
    teacher.append(x3)
    binario = bin(x1+x2)[2:]
    teacher[i] = str(binario)


for k in range(1000):
    if len(n1[k]) < 11:
        for j in range(11-len(n1[k])):
            n1[k] = "0"+n1[k]
    if len(n2[k]) < 11:
        for j in range(11-len(n2[k])):
            n2[k] = "0"+n2[k]
    if len(teacher[k]) < 11:
        for j in range(11-len(teacher[k])):
            teacher[k] = "0"+teacher[k]
    entrada.append(n1[k]+n2[k])


# Conversion de Datos de totales en 1 y -1

for p in range(1000):
    for q in range(22):
        if int(entrada[p][q]) == 1:
            Tensor_Suma_Entrada[p, q] = 1

for p in range(1000):
    for q in range(11):
        if int(teacher[p][q]) == 1:
            Tensor_Teacher_Entrada[p, q] = 1

# Armo el set de entrada

for p in range(0,699):
            Tensor_Suma_Input[p] [:]= Tensor_Suma_Entrada[p][:]
for p1 in range(700,1000):
            Tensor_Suma_Test[p1-700][:] = Tensor_Suma_Entrada[p1][:]
            
for p2 in range(0,699):
            Tensor_Teacher_Input[p2][:] = Tensor_Teacher_Entrada[p2][:]
for p3 in range(700,999): 
            Tensor_Teacher_Test[p3-700][:] = Tensor_Teacher_Entrada[p3][:]


batch_size = 30
epochs = 100

x_train = Tensor_Suma_Input
y_train = Tensor_Teacher_Input
x_test = Tensor_Suma_Test
y_test = Tensor_Teacher_Test

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')


print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout,Activation
from keras.optimizers import adam, sgd,RMSprop,adadelta

model = Sequential([
            Dense(88, kernel_initializer='uniform', input_dim=22),
            Activation('tanh'),
            Dense(88), Activation('sigmoid'),
            Dense(11), Activation('sigmoid')
        ])

model = Sequential([
            Dense(88, kernel_initializer='uniform', input_dim=22),
            Activation('tanh'),
            Dense(88), Activation('sigmoid'),
            Dense(11), Activation('sigmoid')
        ])

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop
              (lr=0.01, rho=0.9, epsilon=None, decay=0.0))


model.compile(loss='categorical_crossentropy',
              optimizer='adadelta',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=1)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

# Get training and test loss histories
training_loss = history.history['loss']
test_loss = history.history['val_loss']

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, test_loss, 'b-')
#plt.plot(batch_size)
#plt.plot(epochs)
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();
# Out:
# 700 train samples
# 300 test samples
# Train on 700 samples, validate on 300 samples
# Epoch 1/100
# 700/700 [==============================] - 3s 4ms/step - loss: 0.1418 - acc: 0.1729 - val_loss: -0.8058 - val_acc: 0.3900
# Epoch 2/100
# 700/700 [==============================] - 0s 220us/step - loss: -0.2715 - acc: 0.1629 - val_loss: -1.7720 - val_acc: 0.4100
# Epoch 3/100
# 700/700 [==============================] - 0s 225us/step - loss: -2.0073 - acc: 0.4386 - val_loss: -4.5223 - val_acc: 0.4933
# Epoch 4/100
# 700/700 [==============================] - 0s 222us/step - loss: -4.8796 - acc: 0.5800 - val_loss: -7.2867 - val_acc: 0.5567
# Epoch 5/100
# 700/700 [==============================] - 0s 224us/step - loss: -6.6421 - acc: 0.5157 - val_loss: -8.4747 - val_acc: 0.3233
# Epoch 6/100
# 700/700 [==============================] - 0s 232us/step - loss: -7.9601 - acc: 0.5357 - val_loss: -10.2877 - val_acc: 0.5400
# Epoch 7/100
# 700/700 [==============================] - 0s 233us/step - loss: -9.5331 - acc: 0.6157 - val_loss: -11.7241 - val_acc: 0.6267
# Epoch 8/100
# 700/700 [==============================] - 0s 245us/step - loss: -10.6123 - acc: 0.6929 - val_loss: -11.9043 - val_acc: 0.7167
# Epoch 9/100
# 700/700 [==============================] - 0s 245us/step - loss: -11.2883 - acc: 0.7471 - val_loss: -13.3150 - val_acc: 0.7367
# Epoch 10/100
# 700/700 [==============================] - 0s 240us/step - loss: -11.8521 - acc: 0.7671 - val_loss: -13.3443 - val_acc: 0.7633
# Epoch 11/100
# 700/700 [==============================] - 0s 228us/step - loss: -12.3599 - acc: 0.8000 - val_loss: -13.2995 - val_acc: 0.7600
# Epoch 12/100
# 700/700 [==============================] - 0s 227us/step - loss: -12.8382 - acc: 0.8114 - val_loss: -13.5169 - val_acc: 0.7767
# Epoch 13/100
# 700/700 [==============================] - 0s 235us/step - loss: -13.1283 - acc: 0.8157 - val_loss: -14.6091 - val_acc: 0.7767
# Epoch 14/100
# 700/700 [==============================] - 0s 218us/step - loss: -13.7292 - acc: 0.8257 - val_loss: -15.1040 - val_acc: 0.8000
# Epoch 15/100
# 700/700 [==============================] - 0s 222us/step - loss: -14.1305 - acc: 0.8286 - val_loss: -15.7013 - val_acc: 0.8100
# Epoch 16/100
# 700/700 [==============================] - 0s 226us/step - loss: -14.4659 - acc: 0.8371 - val_loss: -15.3474 - val_acc: 0.7933
# Epoch 17/100
# 700/700 [==============================] - 0s 201us/step - loss: -14.6846 - acc: 0.8414 - val_loss: -14.9108 - val_acc: 0.8000
# Epoch 18/100
# 700/700 [==============================] - 0s 184us/step - loss: -14.9760 - acc: 0.8471 - val_loss: -16.2873 - val_acc: 0.8100
# Epoch 19/100
# 700/700 [==============================] - 0s 196us/step - loss: -15.0435 - acc: 0.8414 - val_loss: -15.7105 - val_acc: 0.8067
# Epoch 20/100
# 700/700 [==============================] - 0s 223us/step - loss: -15.0421 - acc: 0.8357 - val_loss: -16.2654 - val_acc: 0.8067
# Epoch 21/100
# 700/700 [==============================] - 0s 271us/step - loss: -15.3809 - acc: 0.8400 - val_loss: -16.3323 - val_acc: 0.8100
# Epoch 22/100
# 700/700 [==============================] - 0s 242us/step - loss: -15.4561 - acc: 0.8486 - val_loss: -16.4728 - val_acc: 0.8200
# Epoch 23/100
# 700/700 [==============================] - 0s 236us/step - loss: -15.5791 - acc: 0.8471 - val_loss: -16.5776 - val_acc: 0.8100
# Epoch 24/100
# 700/700 [==============================] - 0s 285us/step - loss: -15.7263 - acc: 0.8529 - val_loss: -16.6691 - val_acc: 0.8200
# Epoch 25/100
# 700/700 [==============================] - 0s 205us/step - loss: -15.7831 - acc: 0.8529 - val_loss: -16.0279 - val_acc: 0.8033
# Epoch 26/100
# 700/700 [==============================] - 0s 199us/step - loss: -15.7406 - acc: 0.8514 - val_loss: -16.5985 - val_acc: 0.8200
# Epoch 27/100
# 700/700 [==============================] - 0s 221us/step - loss: -15.9663 - acc: 0.8557 - val_loss: -16.4566 - val_acc: 0.8167
# Epoch 28/100
# 700/700 [==============================] - 0s 214us/step - loss: -16.0831 - acc: 0.8571 - val_loss: -16.5442 - val_acc: 0.8167
# Epoch 29/100
# 700/700 [==============================] - 0s 216us/step - loss: -16.0384 - acc: 0.8500 - val_loss: -16.7865 - val_acc: 0.8133
# Epoch 30/100
# 700/700 [==============================] - 0s 251us/step - loss: -16.2898 - acc: 0.8557 - val_loss: -16.8255 - val_acc: 0.8167
# Epoch 31/100
# 700/700 [==============================] - 0s 246us/step - loss: -16.4370 - acc: 0.8600 - val_loss: -16.7707 - val_acc: 0.8167
# Epoch 32/100
# 700/700 [==============================] - 0s 235us/step - loss: -16.4101 - acc: 0.8557 - val_loss: -17.0636 - val_acc: 0.8267
# Epoch 33/100
# 700/700 [==============================] - 0s 241us/step - loss: -16.5463 - acc: 0.8500 - val_loss: -16.7022 - val_acc: 0.8267
# Epoch 34/100
# 700/700 [==============================] - 0s 226us/step - loss: -16.5067 - acc: 0.8514 - val_loss: -17.0481 - val_acc: 0.8300
# Epoch 35/100
# 700/700 [==============================] - 0s 202us/step - loss: -16.7777 - acc: 0.8486 - val_loss: -17.2604 - val_acc: 0.8233
# Epoch 36/100
# 700/700 [==============================] - 0s 220us/step - loss: -16.7445 - acc: 0.8429 - val_loss: -17.0326 - val_acc: 0.8267
# Epoch 37/100
# 700/700 [==============================] - 0s 248us/step - loss: -16.9415 - acc: 0.8414 - val_loss: -17.0087 - val_acc: 0.8200
# Epoch 38/100
# 700/700 [==============================] - 0s 230us/step - loss: -17.0266 - acc: 0.8400 - val_loss: -17.1545 - val_acc: 0.8233
# Epoch 39/100
# 700/700 [==============================] - 0s 217us/step - loss: -17.1015 - acc: 0.8357 - val_loss: -17.1646 - val_acc: 0.8167
# Epoch 40/100
# 700/700 [==============================] - 0s 196us/step - loss: -17.1365 - acc: 0.8400 - val_loss: -16.9648 - val_acc: 0.8067
# Epoch 41/100
# 700/700 [==============================] - 0s 200us/step - loss: -17.1552 - acc: 0.8457 - val_loss: -17.1211 - val_acc: 0.8133
# Epoch 42/100
# 700/700 [==============================] - 0s 193us/step - loss: -17.3382 - acc: 0.8386 - val_loss: -17.3531 - val_acc: 0.8167
# Epoch 43/100
# 700/700 [==============================] - 0s 218us/step - loss: -17.4117 - acc: 0.8357 - val_loss: -17.2719 - val_acc: 0.8133
# Epoch 44/100
# 700/700 [==============================] - 0s 232us/step - loss: -17.4709 - acc: 0.8357 - val_loss: -17.3315 - val_acc: 0.8133
# Epoch 45/100
# 700/700 [==============================] - 0s 270us/step - loss: -17.5749 - acc: 0.8314 - val_loss: -17.3789 - val_acc: 0.8133
# Epoch 46/100
# 700/700 [==============================] - 0s 266us/step - loss: -17.6722 - acc: 0.8300 - val_loss: -17.2592 - val_acc: 0.8033
# Epoch 47/100
# 700/700 [==============================] - 0s 231us/step - loss: -17.7095 - acc: 0.8343 - val_loss: -17.5193 - val_acc: 0.8133
# Epoch 48/100
# 700/700 [==============================] - 0s 249us/step - loss: -17.8156 - acc: 0.8286 - val_loss: -17.4830 - val_acc: 0.8100
# Epoch 49/100
# 700/700 [==============================] - 0s 227us/step - loss: -17.9147 - acc: 0.8357 - val_loss: -17.5672 - val_acc: 0.8100
# Epoch 50/100
# 700/700 [==============================] - 0s 234us/step - loss: -18.0124 - acc: 0.8329 - val_loss: -17.6410 - val_acc: 0.8033
# Epoch 51/100
# 700/700 [==============================] - 0s 222us/step - loss: -18.0833 - acc: 0.8329 - val_loss: -17.7366 - val_acc: 0.8033
# Epoch 52/100
# 700/700 [==============================] - 0s 238us/step - loss: -18.1641 - acc: 0.8300 - val_loss: -17.7696 - val_acc: 0.8000
# Epoch 53/100
# 700/700 [==============================] - 0s 236us/step - loss: -18.2890 - acc: 0.8286 - val_loss: -17.9660 - val_acc: 0.8033
# Epoch 54/100
# 700/700 [==============================] - 0s 234us/step - loss: -18.3851 - acc: 0.8300 - val_loss: -17.8375 - val_acc: 0.7967
# Epoch 55/100
# 700/700 [==============================] - 0s 250us/step - loss: -18.4868 - acc: 0.8329 - val_loss: -17.7797 - val_acc: 0.8000
# Epoch 56/100
# 700/700 [==============================] - 0s 225us/step - loss: -18.5463 - acc: 0.8314 - val_loss: -17.8737 - val_acc: 0.7833
# Epoch 57/100
# 700/700 [==============================] - 0s 232us/step - loss: -18.6382 - acc: 0.8314 - val_loss: -18.1056 - val_acc: 0.7867
# Epoch 58/100
# 700/700 [==============================] - 0s 233us/step - loss: -18.7802 - acc: 0.8300 - val_loss: -18.1243 - val_acc: 0.7900
# Epoch 59/100
# 700/700 [==============================] - 0s 286us/step - loss: -18.8623 - acc: 0.8286 - val_loss: -18.2901 - val_acc: 0.7867
# Epoch 60/100
# 700/700 [==============================] - 0s 227us/step - loss: -18.9660 - acc: 0.8257 - val_loss: -18.2405 - val_acc: 0.7867
# Epoch 61/100
# 700/700 [==============================] - 0s 222us/step - loss: -19.1059 - acc: 0.8286 - val_loss: -18.2764 - val_acc: 0.7900
# Epoch 62/100
# 700/700 [==============================] - 0s 232us/step - loss: -19.2063 - acc: 0.8286 - val_loss: -18.3576 - val_acc: 0.7900
# Epoch 63/100
# 700/700 [==============================] - 0s 195us/step - loss: -19.2927 - acc: 0.8271 - val_loss: -18.3892 - val_acc: 0.7867
# Epoch 64/100
# 700/700 [==============================] - 0s 216us/step - loss: -19.3861 - acc: 0.8243 - val_loss: -18.4030 - val_acc: 0.7900
# Epoch 65/100
# 700/700 [==============================] - 0s 232us/step - loss: -19.5310 - acc: 0.8343 - val_loss: -18.4785 - val_acc: 0.7867
# Epoch 66/100
# 700/700 [==============================] - 0s 233us/step - loss: -19.6126 - acc: 0.8286 - val_loss: -18.5362 - val_acc: 0.7967
# Epoch 67/100
# 700/700 [==============================] - 0s 226us/step - loss: -19.7147 - acc: 0.8329 - val_loss: -18.6682 - val_acc: 0.7900
# Epoch 68/100
# 700/700 [==============================] - 0s 216us/step - loss: -19.8410 - acc: 0.8400 - val_loss: -18.6966 - val_acc: 0.7933
# Epoch 69/100
# 700/700 [==============================] - 0s 221us/step - loss: -19.9469 - acc: 0.8314 - val_loss: -18.7311 - val_acc: 0.7900
# Epoch 70/100
# 700/700 [==============================] - 0s 219us/step - loss: -20.0428 - acc: 0.8329 - val_loss: -18.5722 - val_acc: 0.7967
# Epoch 71/100
# 700/700 [==============================] - 0s 216us/step - loss: -20.1377 - acc: 0.8386 - val_loss: -18.8836 - val_acc: 0.8067
# Epoch 72/100
# 700/700 [==============================] - 0s 209us/step - loss: -20.2697 - acc: 0.8400 - val_loss: -18.8606 - val_acc: 0.8100
# Epoch 73/100
# 700/700 [==============================] - 0s 218us/step - loss: -20.3595 - acc: 0.8386 - val_loss: -18.9961 - val_acc: 0.8033
# Epoch 74/100
# 700/700 [==============================] - 0s 209us/step - loss: -20.4746 - acc: 0.8443 - val_loss: -18.9682 - val_acc: 0.8000
# Epoch 75/100
# 700/700 [==============================] - 0s 201us/step - loss: -20.5730 - acc: 0.8414 - val_loss: -18.9672 - val_acc: 0.8000
# Epoch 76/100
# 700/700 [==============================] - 0s 225us/step - loss: -20.6944 - acc: 0.8400 - val_loss: -19.0102 - val_acc: 0.8100
# Epoch 77/100
# 700/700 [==============================] - 0s 191us/step - loss: -20.8056 - acc: 0.8471 - val_loss: -19.2321 - val_acc: 0.8100
# Epoch 78/100
# 700/700 [==============================] - 0s 182us/step - loss: -20.9121 - acc: 0.8471 - val_loss: -19.1989 - val_acc: 0.8133
# Epoch 79/100
# 700/700 [==============================] - 0s 196us/step - loss: -21.0003 - acc: 0.8457 - val_loss: -19.2259 - val_acc: 0.8133
# Epoch 80/100
# 700/700 [==============================] - 0s 194us/step - loss: -21.1357 - acc: 0.8414 - val_loss: -19.3392 - val_acc: 0.8233
# Epoch 81/100
# 700/700 [==============================] - 0s 193us/step - loss: -21.1984 - acc: 0.8529 - val_loss: -19.4543 - val_acc: 0.8233
# Epoch 82/100
# 700/700 [==============================] - 0s 200us/step - loss: -21.3319 - acc: 0.8443 - val_loss: -19.4325 - val_acc: 0.8200
# Epoch 83/100
# 700/700 [==============================] - 0s 222us/step - loss: -21.4335 - acc: 0.8543 - val_loss: -19.5482 - val_acc: 0.8200
# Epoch 84/100
# 700/700 [==============================] - 0s 206us/step - loss: -21.5269 - acc: 0.8486 - val_loss: -19.4421 - val_acc: 0.8200
# Epoch 85/100
# 700/700 [==============================] - 0s 194us/step - loss: -21.6239 - acc: 0.8514 - val_loss: -19.6508 - val_acc: 0.8200
# Epoch 86/100
# 700/700 [==============================] - 0s 208us/step - loss: -21.7329 - acc: 0.8414 - val_loss: -19.6777 - val_acc: 0.8200
# Epoch 87/100
# 700/700 [==============================] - 0s 232us/step - loss: -21.8234 - acc: 0.8514 - val_loss: -19.7691 - val_acc: 0.8200
# Epoch 88/100
# 700/700 [==============================] - 0s 230us/step - loss: -21.9216 - acc: 0.8386 - val_loss: -19.8714 - val_acc: 0.8200
# Epoch 89/100
# 700/700 [==============================] - 0s 247us/step - loss: -22.0129 - acc: 0.8443 - val_loss: -19.8122 - val_acc: 0.8200
# Epoch 90/100
# 700/700 [==============================] - 0s 221us/step - loss: -22.0946 - acc: 0.8471 - val_loss: -19.8426 - val_acc: 0.8200
# Epoch 91/100
# 700/700 [==============================] - 0s 190us/step - loss: -22.1884 - acc: 0.8443 - val_loss: -19.9107 - val_acc: 0.8200
# Epoch 92/100
# 700/700 [==============================] - 0s 228us/step - loss: -22.2897 - acc: 0.8457 - val_loss: -19.9508 - val_acc: 0.8200
# Epoch 93/100
# 700/700 [==============================] - 0s 198us/step - loss: -22.3606 - acc: 0.8414 - val_loss: -19.9588 - val_acc: 0.8200
# Epoch 94/100
# 700/700 [==============================] - 0s 196us/step - loss: -22.4481 - acc: 0.8386 - val_loss: -19.9287 - val_acc: 0.8200
# Epoch 95/100
# 700/700 [==============================] - 0s 184us/step - loss: -22.5245 - acc: 0.8414 - val_loss: -20.1030 - val_acc: 0.8100
# Epoch 96/100
# 700/700 [==============================] - 0s 217us/step - loss: -22.6162 - acc: 0.8343 - val_loss: -20.0937 - val_acc: 0.8200
# Epoch 97/100
# 700/700 [==============================] - 0s 213us/step - loss: -22.6933 - acc: 0.8443 - val_loss: -20.1141 - val_acc: 0.8200
# Epoch 98/100
# 700/700 [==============================] - 0s 181us/step - loss: -22.7774 - acc: 0.8429 - val_loss: -20.1622 - val_acc: 0.8200
# Epoch 99/100
# 700/700 [==============================] - 0s 214us/step - loss: -22.8428 - acc: 0.8400 - val_loss: -20.1929 - val_acc: 0.8167
# Epoch 100/100
# 700/700 [==============================] - 0s 230us/step - loss: -22.9282 - acc: 0.8371 - val_loss: -20.1767 - val_acc: 0.8200
# 300/300 [==============================] - 0s 134us/step
# Test loss: -20.17669860839844
# Test accuracy: 0.8199999992052714
