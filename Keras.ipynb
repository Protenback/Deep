# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n1 = []
n2 = []
teacher = []
# entrada = np.arange(80)
entrada = []
binario = " "

Tensor_Suma_Entrada = np.ones((1000, 22))*(-1)
Tensor_Suma_Input = np.ones((700, 22))*(-1)
Tensor_Suma_Test = np.ones((300, 22))*(-1)

Tensor_Teacher_Entrada = np.ones((1000, 11))*(-1)
Tensor_Teacher_Input = np.ones((700, 11))*(-1)
Tensor_Teacher_Test = np.ones((300, 11))*(-1)


for i in range(1000):

    n1.append(random.randrange(1, 1000))
    x1 = n1[i]
    binario = bin(n1[i])[2:]
    n1[i] = str(binario)

    n2.append(random.randrange(1, 1000))
    x2 = n2[i]
    binario = bin(n2[i])[2:]
    n2[i] = str(binario)

    x3 = x1+x2
    teacher.append(x3)
    binario = bin(x1+x2)[2:]
    teacher[i] = str(binario)


for k in range(1000):
    if len(n1[k]) < 11:
        for j in range(11-len(n1[k])):
            n1[k] = "0"+n1[k]
    if len(n2[k]) < 11:
        for j in range(11-len(n2[k])):
            n2[k] = "0"+n2[k]
    if len(teacher[k]) < 11:
        for j in range(11-len(teacher[k])):
            teacher[k] = "0"+teacher[k]
    entrada.append(n1[k]+n2[k])


# Conversion de Datos de totales en 1 y -1

for p in range(1000):
    for q in range(22):
        if int(entrada[p][q]) == 1:
            Tensor_Suma_Entrada[p, q] = 1

for p in range(1000):
    for q in range(11):
        if int(teacher[p][q]) == 1:
            Tensor_Teacher_Entrada[p, q] = 1

# Armo el set de entrada

for p in range(0,699):
            Tensor_Suma_Input[p] [:]= Tensor_Suma_Entrada[p][:]
for p1 in range(700,1000):
            Tensor_Suma_Test[p1-700][:] = Tensor_Suma_Entrada[p1][:]
            
for p2 in range(0,699):
            Tensor_Teacher_Input[p2][:] = Tensor_Teacher_Entrada[p2][:]
for p3 in range(700,999): 
            Tensor_Teacher_Test[p3-700][:] = Tensor_Teacher_Entrada[p3][:]


batch_size = 30
epochs = 100

x_train = Tensor_Suma_Input
y_train = Tensor_Teacher_Input
x_test = Tensor_Suma_Test
y_test = Tensor_Teacher_Test

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')


print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout,Activation
from keras.optimizers import adam, sgd,RMSprop,adadelta

model = Sequential([
            Dense(88, kernel_initializer='uniform', input_dim=22),
            Activation('tanh'),
            Dense(88), Activation('sigmoid'),
            Dense(11), Activation('sigmoid')
        ])

model = Sequential([
            Dense(88, kernel_initializer='uniform', input_dim=22),
            Activation('tanh'),
            Dense(88), Activation('sigmoid'),
            Dense(11), Activation('sigmoid')
        ])

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop
              (lr=0.01, rho=0.9, epsilon=None, decay=0.0))


model.compile(loss='categorical_crossentropy',
              optimizer='adadelta',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=1)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

# Get training and test loss histories
training_loss = history.history['loss']
test_loss = history.history['val_loss']

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, test_loss, 'b-')
#plt.plot(batch_size)
#plt.plot(epochs)
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();
# Out:
# 700 train samples
# 300 test samples
# Train on 700 samples, validate on 300 samples
# Epoch 1/100
# 700/700 [==============================] - 0s 666us/step - loss: -0.8063 - acc: 0.0000e+00 - val_loss: -0.1539 - val_acc: 0.0000e+00
# Epoch 2/100
# 700/700 [==============================] - 0s 225us/step - loss: -1.4228 - acc: 0.0000e+00 - val_loss: -1.4042 - val_acc: 0.0000e+00
# Epoch 3/100
# 700/700 [==============================] - 0s 198us/step - loss: -5.0607 - acc: 0.0929 - val_loss: -5.3424 - val_acc: 0.2633
# Epoch 4/100
# 700/700 [==============================] - 0s 172us/step - loss: -7.6342 - acc: 0.3100 - val_loss: -5.6868 - val_acc: 0.3233
# Epoch 5/100
# 700/700 [==============================] - 0s 164us/step - loss: -8.4554 - acc: 0.3614 - val_loss: -6.3418 - val_acc: 0.3667
# Epoch 6/100
# 700/700 [==============================] - 0s 228us/step - loss: -9.2490 - acc: 0.3943 - val_loss: -6.7295 - val_acc: 0.4000
# Epoch 7/100
# 700/700 [==============================] - 0s 153us/step - loss: -10.0367 - acc: 0.4257 - val_loss: -7.0954 - val_acc: 0.4900
# Epoch 8/100
# 700/700 [==============================] - 0s 201us/step - loss: -10.9638 - acc: 0.5786 - val_loss: -8.2290 - val_acc: 0.5767
# Epoch 9/100
# 700/700 [==============================] - 0s 168us/step - loss: -11.8237 - acc: 0.6143 - val_loss: -8.6092 - val_acc: 0.6100
# Epoch 10/100
# 700/700 [==============================] - 0s 156us/step - loss: -12.7777 - acc: 0.6429 - val_loss: -9.3574 - val_acc: 0.6867
# Epoch 11/100
# 700/700 [==============================] - 0s 171us/step - loss: -13.6268 - acc: 0.6971 - val_loss: -9.8678 - val_acc: 0.7400
# Epoch 12/100
# 700/700 [==============================] - 0s 232us/step - loss: -14.2880 - acc: 0.7371 - val_loss: -10.6096 - val_acc: 0.8000
# Epoch 13/100
# 700/700 [==============================] - 0s 205us/step - loss: -14.6939 - acc: 0.7686 - val_loss: -10.1787 - val_acc: 0.7767
# Epoch 14/100
# 700/700 [==============================] - 0s 182us/step - loss: -15.1207 - acc: 0.7771 - val_loss: -10.9843 - val_acc: 0.8067
# Epoch 15/100
# 700/700 [==============================] - 0s 190us/step - loss: -15.5525 - acc: 0.7871 - val_loss: -10.6053 - val_acc: 0.8067
# Epoch 16/100
# 700/700 [==============================] - 0s 238us/step - loss: -16.1686 - acc: 0.8000 - val_loss: -11.0644 - val_acc: 0.8133
# Epoch 17/100
# 700/700 [==============================] - 0s 240us/step - loss: -16.2403 - acc: 0.7929 - val_loss: -10.1506 - val_acc: 0.7967
# Epoch 18/100
# 700/700 [==============================] - 0s 218us/step - loss: -16.8160 - acc: 0.8086 - val_loss: -11.9217 - val_acc: 0.8367
# Epoch 19/100
# 700/700 [==============================] - 0s 222us/step - loss: -17.3171 - acc: 0.8057 - val_loss: -11.9286 - val_acc: 0.8267
# Epoch 20/100
# 700/700 [==============================] - 0s 193us/step - loss: -17.4648 - acc: 0.7957 - val_loss: -11.7863 - val_acc: 0.8267
# 700/700 [==============================] - 0s 208us/step - loss: -24.0686 - acc: 0.7557 - val_loss: -13.9822 - val_acc: 0.7900
# Epoch 83/100
# 700/700 [==============================] - 0s 214us/step - loss: -24.1355 - acc: 0.7514 - val_loss: -14.2899 - val_acc: 0.7933
# Epoch 84/100
# 700/700 [==============================] - 0s 184us/step - loss: -24.1965 - acc: 0.7543 - val_loss: -14.1037 - val_acc: 0.7967
# Epoch 85/100
# 700/700 [==============================] - 0s 198us/step - loss: -24.2758 - acc: 0.7514 - val_loss: -14.0947 - val_acc: 0.7900
# Epoch 86/100
# 700/700 [==============================] - 0s 198us/step - loss: -24.3585 - acc: 0.7543 - val_loss: -14.1209 - val_acc: 0.7867
# Epoch 87/100
# 700/700 [==============================] - 0s 173us/step - loss: -24.4244 - acc: 0.7500 - val_loss: -14.3136 - val_acc: 0.8000
# Epoch 88/100
# 700/700 [==============================] - 0s 215us/step - loss: -24.5002 - acc: 0.7500 - val_loss: -14.1801 - val_acc: 0.7967
# Epoch 89/100
# 700/700 [==============================] - 0s 178us/step - loss: -24.5742 - acc: 0.7571 - val_loss: -14.3516 - val_acc: 0.7933
# Epoch 90/100
# 700/700 [==============================] - 0s 175us/step - loss: -24.6411 - acc: 0.7386 - val_loss: -14.1823 - val_acc: 0.7933
# Epoch 91/100
# 700/700 [==============================] - 0s 217us/step - loss: -24.7172 - acc: 0.7529 - val_loss: -14.3458 - val_acc: 0.8000
# Epoch 92/100
# 700/700 [==============================] - 0s 238us/step - loss: -24.8160 - acc: 0.7486 - val_loss: -14.4087 - val_acc: 0.7967
# Epoch 93/100
# 700/700 [==============================] - 0s 172us/step - loss: -24.8869 - acc: 0.7543 - val_loss: -14.3777 - val_acc: 0.7833
# Epoch 94/100
# 700/700 [==============================] - 0s 167us/step - loss: -24.9711 - acc: 0.7486 - val_loss: -14.4283 - val_acc: 0.7967
# Epoch 95/100
# 700/700 [==============================] - 0s 215us/step - loss: -25.0410 - acc: 0.7529 - val_loss: -14.4716 - val_acc: 0.7833
# Epoch 96/100
# 700/700 [==============================] - 0s 198us/step - loss: -25.1309 - acc: 0.7514 - val_loss: -14.4333 - val_acc: 0.7733
# Epoch 97/100
# 700/700 [==============================] - 0s 203us/step - loss: -25.2089 - acc: 0.7471 - val_loss: -14.6105 - val_acc: 0.7767
# Epoch 98/100
# 700/700 [==============================] - 0s 195us/step - loss: -25.3019 - acc: 0.7357 - val_loss: -14.7372 - val_acc: 0.7767
# Epoch 99/100
# 700/700 [==============================] - 0s 213us/step - loss: -25.3854 - acc: 0.7357 - val_loss: -14.6296 - val_acc: 0.7733
# Epoch 100/100
# 700/700 [==============================] - 0s 236us/step - loss: -25.4832 - acc: 0.7343 - val_loss: -14.6586 - val_acc: 0.7733
# 300/300 [==============================] - 0s 115us/step
# Test loss: -14.658621775309244
# Test accuracy: 0.7733333333333333

# %%
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, test_loss, 'b-')
#plt.plot(batch_size)
#plt.plot(epochs)
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();
